# %% [markdown]
# # Tahoe-100M centroid-level integration (scBIOT 1.2.0)
#
# This is the intentionally **large-scale, non-CI** tutorial. It is updated to the v1.2.0 API but excluded from the notebook execution check because it requires the Tahoe-100M plates and an out-of-core PCA/AE embedding.
#
# - Source dataset and preprocessing: [Tahoe-100M analysis](https://theislab.github.io/vevo_Tahoe_100m_analysis/)
# - Dataset record: [Tahoe-100M on CELLxGENE](https://cellxgene.cziscience.com/collections/6b9fc6ad-05f0-4e9e-95a3-42c8f80c8f0b)
#
# Set `TAHOE_EMBEDDING_H5AD` to an AnnData containing `obs["plate"]` and `obsm["X_ae"]` (or set `TAHOE_INPUT_REP` to a different prepared representation).

# %%
from pathlib import Path
import os
import scanpy as sc
import scbiot as scb

path = os.environ.get("TAHOE_EMBEDDING_H5AD")
if not path:
    raise RuntimeError("Set TAHOE_EMBEDDING_H5AD to the prepared Tahoe-100M AnnData.")
adata = sc.read_h5ad(Path(path), backed="r+")
rep_key = os.environ.get("TAHOE_INPUT_REP", "X_ae")
adata

# %% [markdown]
# ## Centroid OT with v1.2.0 parameters

# %%
adata, metrics = scb.ot.integrate(
    adata, obsm_key=rep_key, batch_key="plate", out_key="X_ot",
    centroid=True, n_centroids_per_batch=2048,
    max_samples_per_batch=500_000, k_interp=8, chunk_size=500_000,
    random_state=0,
    use_gpu=USE_GPU,
)
metrics

# %% [markdown]
# For full preprocessing and out-of-core PCA construction, follow the linked Tahoe-100M source workflow. Save `X_ot` into the same backed AnnData or a Zarr store before visualization.
