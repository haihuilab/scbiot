# %% [markdown]
# # scBIOT 1.2.0 pipeline schematic
#
# The executable tutorials implement these paths:
#
# - scRNA-seq: linear autoencoder → `scbiot.ot.integrate()`
# - semi-supervised annotation: linear autoencoder → `integrate()` → `supbiot()`
# - paired/unpaired multi-omics: `autoencoder_map()` → `integrate()` → `supbiot()`
# - spatiotemporal dynamics: linear autoencoder → spatial/time-aware `integrate()` → transport tools

# %%
import scbiot as scb
print("scBIOT", scb.__version__)
